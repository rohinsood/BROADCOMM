# %%
import subprocess
import pandas as pd
import matplotlib.pyplot as plt
import time

# %%
# !sudo apt install traceroute
# Out:
# [sudo] password for rohinsood:

# %%
# !traceroute google.com
# Out:
# /bin/bash: line 1: traceroute: command not found

# %%
ip_addresses = ["192.168.1.1", "8.8.8.8", "1.1.1.1"]
request_count = 1000
csv_file = 'ping_results.csv'

# %%
# Function to ping an IP address and return the latency
def ping(ip):
    try:
        output = subprocess.run(["ping", "-c", "1", ip], capture_output=True, text=True, timeout=2)
        if "time=" in output.stdout:
            latency = output.stdout.split("time=")[1].split(" ms")[0]
            return float(latency)
        else:
            return None
    except subprocess.TimeoutExpired:
        return None

# %%
df = pd.DataFrame(columns=['Request Number', f'{ip_addresses[0]} Latency (ms)', f'{ip_addresses[1]} Latency (ms)', f'{ip_addresses[2]} Latency (ms)'])

# ping 1000 times
for i in range(1, request_count + 1):
    row = [i]
    for ip in ip_addresses:
        latency = ping(ip)
        row.append(latency if latency is not None else None)  # Use None for timeouts
    df.loc[i - 1] = row
    print(f"Request {i} completed.")
    time.sleep(0.1)

# Save df to CSV
df.to_csv(csv_file, index=False)
print(f"Results saved to {csv_file}")
# Out:
# Request 1 completed.
# Request 2 completed.
# Request 3 completed.
# Request 4 completed.
# Request 5 completed.
# Request 6 completed.
# Request 7 completed.
# Request 8 completed.
# Request 9 completed.
# Request 10 completed.
# Request 11 completed.
# Request 12 completed.
# Request 13 completed.
# Request 14 completed.
# Request 15 completed.
# Request 16 completed.
# Request 17 completed.
# Request 18 completed.
# Request 19 completed.
# Request 20 completed.
# Request 21 completed.
# Request 22 completed.
# Request 23 completed.
# Request 24 completed.
# Request 25 completed.
# Request 26 completed.
# Request 27 completed.
# Request 28 completed.
# Request 29 completed.
# Request 30 completed.
# Request 31 completed.
# Request 32 completed.
# Request 33 completed.
# Request 34 completed.
# Request 35 completed.
# Request 36 completed.
# Request 37 completed.
# Request 38 completed.
# Request 39 completed.
# Request 40 completed.
# Request 41 completed.
# Request 42 completed.
# Request 43 completed.
# Request 44 completed.
# Request 45 completed.
# Request 46 completed.
# Request 47 completed.
# Request 48 completed.
# Request 49 completed.
# Request 50 completed.
# Request 51 completed.
# Request 52 completed.
# Request 53 completed.
# Request 54 completed.
# Request 55 completed.
# Request 56 completed.
# Request 57 completed.
# Request 58 completed.
# Request 59 completed.
# Request 60 completed.
# Request 61 completed.
# Request 62 completed.
# Request 63 completed.
# Request 64 completed.
# Request 65 completed.
# Request 66 completed.
# Request 67 completed.
# Request 68 completed.
# Request 69 completed.
# Request 70 completed.
# Request 71 completed.
# Request 72 completed.
# Request 73 completed.
# Request 74 completed.
# Request 75 completed.
# Request 76 completed.
# Request 77 completed.
# Request 78 completed.
# Request 79 completed.
# Request 80 completed.
# Request 81 completed.
# Request 82 completed.
# Request 83 completed.
# Request 84 completed.
# Request 85 completed.
# Request 86 completed.
# Request 87 completed.
# Request 88 completed.
# Request 89 completed.
# Request 90 completed.
# Request 91 completed.
# Request 92 completed.
# Request 93 completed.
# Request 94 completed.
# Request 95 completed.
# Request 96 completed.
# Request 97 completed.
# Request 98 completed.
# Request 99 completed.
# Request 100 completed.
# Request 101 completed.
# Request 102 completed.
# Request 103 completed.
# Request 104 completed.
# Request 105 completed.
# Request 106 completed.
# Request 107 completed.
# Request 108 completed.
# Request 109 completed.
# Request 110 completed.
# Request 111 completed.
# Request 112 completed.
# Request 113 completed.
# Request 114 completed.
# Request 115 completed.
# Request 116 completed.
# Request 117 completed.
# Request 118 completed.
# Request 119 completed.
# Request 120 completed.
# Request 121 completed.
# Request 122 completed.
# Request 123 completed.
# Request 124 completed.
# Request 125 completed.
# Request 126 completed.
# Request 127 completed.
# Request 128 completed.
# Request 129 completed.
# Request 130 completed.
# Request 131 completed.
# Request 132 completed.
# Request 133 completed.
# Request 134 completed.
# Request 135 completed.
# Request 136 completed.
# Request 137 completed.
# Request 138 completed.
# Request 139 completed.
# Request 140 completed.
# Request 141 completed.
# Request 142 completed.
# Request 143 completed.
# Request 144 completed.
# Request 145 completed.
# Request 146 completed.
# Request 147 completed.
# Request 148 completed.
# Request 149 completed.
# Request 150 completed.
# Request 151 completed.
# Request 152 completed.
# Request 153 completed.
# Request 154 completed.
# Request 155 completed.
# Request 156 completed.
# Request 157 completed.
# Request 158 completed.
# Request 159 completed.
# Request 160 completed.
# Request 161 completed.
# Request 162 completed.
# Request 163 completed.
# Request 164 completed.
# Request 165 completed.
# Request 166 completed.
# Request 167 completed.
# Request 168 completed.
# Request 169 completed.
# Request 170 completed.
# Request 171 completed.
# Request 172 completed.
# Request 173 completed.
# Request 174 completed.
# Request 175 completed.
# Request 176 completed.
# Request 177 completed.
# Request 178 completed.
# Request 179 completed.
# Request 180 completed.
# Request 181 completed.
# Request 182 completed.
# Request 183 completed.
# Request 184 completed.
# Request 185 completed.
# Request 186 completed.
# Request 187 completed.
# Request 188 completed.
# Request 189 completed.
# Request 190 completed.
# Request 191 completed.
# Request 192 completed.
# Request 193 completed.
# Request 194 completed.
# Request 195 completed.
# Request 196 completed.
# Request 197 completed.
# Request 198 completed.
# Request 199 completed.
# Request 200 completed.
# Request 201 completed.
# Request 202 completed.
# Request 203 completed.
# Request 204 completed.
# Request 205 completed.
# Request 206 completed.
# Request 207 completed.
# Request 208 completed.
# Request 209 completed.
# Request 210 completed.
# Request 211 completed.
# Request 212 completed.
# Request 213 completed.
# Request 214 completed.
# Request 215 completed.
# Request 216 completed.
# Request 217 completed.
# Request 218 completed.
# Request 219 completed.
# Request 220 completed.
# Request 221 completed.
# Request 222 completed.
# Request 223 completed.
# Request 224 completed.
# Request 225 completed.
# Request 226 completed.
# Request 227 completed.
# Request 228 completed.
# Request 229 completed.
# Request 230 completed.
# Request 231 completed.
# Request 232 completed.
# Request 233 completed.
# Request 234 completed.
# Request 235 completed.
# Request 236 completed.
# Request 237 completed.
# Request 238 completed.
# Request 239 completed.
# Request 240 completed.
# Request 241 completed.
# Request 242 completed.
# Request 243 completed.
# Request 244 completed.
# Request 245 completed.
# Request 246 completed.
# Request 247 completed.
# Request 248 completed.
# Request 249 completed.
# Request 250 completed.
# Request 251 completed.
# Request 252 completed.
# Request 253 completed.
# Request 254 completed.
# Request 255 completed.
# Request 256 completed.
# Request 257 completed.
# Request 258 completed.
# Request 259 completed.
# Request 260 completed.
# Request 261 completed.
# Request 262 completed.
# Request 263 completed.
# Request 264 completed.
# Request 265 completed.
# Request 266 completed.
# Request 267 completed.
# Request 268 completed.
# Request 269 completed.
# Request 270 completed.
# Request 271 completed.
# Request 272 completed.
# Request 273 completed.
# Request 274 completed.
# Request 275 completed.
# Request 276 completed.
# Request 277 completed.
# Request 278 completed.
# Request 279 completed.
# Request 280 completed.
# Request 281 completed.
# Request 282 completed.
# Request 283 completed.
# Request 284 completed.
# Request 285 completed.
# Request 286 completed.
# Request 287 completed.
# Request 288 completed.
# Request 289 completed.
# Request 290 completed.
# Request 291 completed.
# Request 292 completed.
# Request 293 completed.
# Request 294 completed.
# Request 295 completed.
# Request 296 completed.
# Request 297 completed.
# Request 298 completed.
# Request 299 completed.
# Request 300 completed.
# Request 301 completed.
# Request 302 completed.
# Request 303 completed.
# Request 304 completed.
# Request 305 completed.
# Request 306 completed.
# Request 307 completed.
# Request 308 completed.
# Request 309 completed.
# Request 310 completed.
# Request 311 completed.
# Request 312 completed.
# Request 313 completed.
# Request 314 completed.
# Request 315 completed.
# Request 316 completed.
# Request 317 completed.
# Request 318 completed.
# Request 319 completed.
# Request 320 completed.
# Request 321 completed.
# Request 322 completed.
# Request 323 completed.
# Request 324 completed.
# Request 325 completed.
# Request 326 completed.
# Request 327 completed.
# Request 328 completed.
# Request 329 completed.
# Request 330 completed.
# Request 331 completed.
# Request 332 completed.
# Request 333 completed.
# Request 334 completed.
# Request 335 completed.
# Request 336 completed.
# Request 337 completed.
# Request 338 completed.
# Request 339 completed.
# Request 340 completed.
# Request 341 completed.
# Request 342 completed.
# Request 343 completed.
# Request 344 completed.
# Request 345 completed.
# Request 346 completed.
# Request 347 completed.
# Request 348 completed.
# Request 349 completed.
# Request 350 completed.
# Request 351 completed.
# Request 352 completed.
# Request 353 completed.
# Request 354 completed.
# Request 355 completed.
# Request 356 completed.
# Request 357 completed.
# Request 358 completed.
# Request 359 completed.
# Request 360 completed.
# Request 361 completed.
# Request 362 completed.
# Request 363 completed.
# Request 364 completed.
# Request 365 completed.
# Request 366 completed.
# Request 367 completed.
# Request 368 completed.
# Request 369 completed.
# Request 370 completed.
# Request 371 completed.
# Request 372 completed.
# Request 373 completed.
# Request 374 completed.
# Request 375 completed.
# Request 376 completed.
# Request 377 completed.
# Request 378 completed.
# Request 379 completed.
# Request 380 completed.
# Request 381 completed.
# Request 382 completed.
# Request 383 completed.
# Request 384 completed.
# Request 385 completed.
# Request 386 completed.
# Request 387 completed.
# Request 388 completed.
# Request 389 completed.
# Request 390 completed.
# Request 391 completed.
# Request 392 completed.
# Request 393 completed.
# Request 394 completed.
# Request 395 completed.
# Request 396 completed.
# Request 397 completed.
# Request 398 completed.
# Request 399 completed.
# Request 400 completed.
# Request 401 completed.
# Request 402 completed.
# Request 403 completed.
# Request 404 completed.
# Request 405 completed.
# Request 406 completed.
# Request 407 completed.
# Request 408 completed.
# Request 409 completed.
# Request 410 completed.
# Request 411 completed.
# Request 412 completed.
# Request 413 completed.
# Request 414 completed.
# Request 415 completed.
# Request 416 completed.
# Request 417 completed.
# Request 418 completed.
# Request 419 completed.
# Request 420 completed.
# Request 421 completed.
# Request 422 completed.
# Request 423 completed.
# Request 424 completed.
# Request 425 completed.
# Request 426 completed.
# Request 427 completed.
# Request 428 completed.
# Request 429 completed.
# Request 430 completed.
# Request 431 completed.
# Request 432 completed.
# Request 433 completed.
# Request 434 completed.
# Request 435 completed.
# Request 436 completed.
# Request 437 completed.
# Request 438 completed.
# Request 439 completed.
# Request 440 completed.
# Request 441 completed.
# Request 442 completed.
# Request 443 completed.
# Request 444 completed.
# Request 445 completed.
# Request 446 completed.
# Request 447 completed.
# Request 448 completed.
# Request 449 completed.
# Request 450 completed.
# Request 451 completed.
# Request 452 completed.
# Request 453 completed.
# Request 454 completed.
# Request 455 completed.
# Request 456 completed.
# Request 457 completed.
# Request 458 completed.
# Request 459 completed.
# Request 460 completed.
# Request 461 completed.
# Request 462 completed.
# Request 463 completed.
# Request 464 completed.
# Request 465 completed.
# Request 466 completed.
# Request 467 completed.
# Request 468 completed.
# Request 469 completed.
# Request 470 completed.
# Request 471 completed.
# Request 472 completed.
# Request 473 completed.
# Request 474 completed.
# Request 475 completed.
# Request 476 completed.
# Request 477 completed.
# Request 478 completed.
# Request 479 completed.
# Request 480 completed.
# Request 481 completed.
# Request 482 completed.
# Request 483 completed.
# Request 484 completed.
# Request 485 completed.
# Request 486 completed.
# Request 487 completed.
# Request 488 completed.
# Request 489 completed.
# Request 490 completed.
# Request 491 completed.
# Request 492 completed.
# Request 493 completed.
# Request 494 completed.
# Request 495 completed.
# Request 496 completed.
# Request 497 completed.
# Request 498 completed.
# Request 499 completed.
# Request 500 completed.
# Request 501 completed.
# Request 502 completed.
# Request 503 completed.
# Request 504 completed.
# Request 505 completed.
# Request 506 completed.
# Request 507 completed.
# Request 508 completed.
# Request 509 completed.
# Request 510 completed.
# Request 511 completed.
# Request 512 completed.
# Request 513 completed.
# Request 514 completed.
# Request 515 completed.
# Request 516 completed.
# Request 517 completed.
# Request 518 completed.
# Request 519 completed.
# Request 520 completed.
# Request 521 completed.
# Request 522 completed.
# Request 523 completed.
# Request 524 completed.
# Request 525 completed.
# Request 526 completed.
# Request 527 completed.
# Request 528 completed.
# Request 529 completed.
# Request 530 completed.
# Request 531 completed.
# Request 532 completed.
# Request 533 completed.
# Request 534 completed.
# Request 535 completed.
# Request 536 completed.
# Request 537 completed.
# Request 538 completed.
# Request 539 completed.
# Request 540 completed.
# Request 541 completed.
# Request 542 completed.
# Request 543 completed.
# Request 544 completed.
# Request 545 completed.
# Request 546 completed.
# Request 547 completed.
# Request 548 completed.
# Request 549 completed.
# Request 550 completed.
# Request 551 completed.
# Request 552 completed.
# Request 553 completed.
# Request 554 completed.
# Request 555 completed.
# Request 556 completed.
# Request 557 completed.
# Request 558 completed.
# Request 559 completed.
# Request 560 completed.
# Request 561 completed.
# Request 562 completed.
# Request 563 completed.
# Request 564 completed.
# Request 565 completed.
# Request 566 completed.
# Request 567 completed.
# Request 568 completed.
# Request 569 completed.
# Request 570 completed.
# Request 571 completed.
# Request 572 completed.
# Request 573 completed.
# Request 574 completed.
# Request 575 completed.
# Request 576 completed.
# Request 577 completed.
# Request 578 completed.
# Request 579 completed.
# Request 580 completed.
# Request 581 completed.
# Request 582 completed.
# Request 583 completed.
# Request 584 completed.
# Request 585 completed.
# Request 586 completed.
# Request 587 completed.
# Request 588 completed.
# Request 589 completed.
# Request 590 completed.
# Request 591 completed.
# Request 592 completed.
# Request 593 completed.
# Request 594 completed.
# Request 595 completed.
# Request 596 completed.
# Request 597 completed.
# Request 598 completed.
# Request 599 completed.
# Request 600 completed.
# Request 601 completed.
# Request 602 completed.
# Request 603 completed.
# Request 604 completed.
# Request 605 completed.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 8
#       6 row = [i]
#       7 for ip in ip_addresses:
# ----> 8     latency = ping(ip)
#       9     row.append(latency if latency is not None else None)  # Use None for timeouts
#      10 df.loc[i - 1] = row
#
# Cell In[4], line 4, in ping(ip)
#       2 def ping(ip):
#       3     try:
# ----> 4         output = subprocess.run(["ping", "-c", "1", ip], capture_output=True, text=True, timeout=2)
#       5         if "time=" in output.stdout:
#       6             latency = output.stdout.split("time=")[1].split(" ms")[0]
#
# File /usr/lib/python3.10/subprocess.py:505, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     503 with Popen(*popenargs, **kwargs) as process:
#     504     try:
# --> 505         stdout, stderr = process.communicate(input, timeout=timeout)
#     506     except TimeoutExpired as exc:
#     507         process.kill()
#
# File /usr/lib/python3.10/subprocess.py:1154, in Popen.communicate(self, input, timeout)
#    1151     endtime = None
#    1153 try:
# -> 1154     stdout, stderr = self._communicate(input, endtime, timeout)
#    1155 except KeyboardInterrupt:
#    1156     # https://bugs.python.org/issue25942
#    1157     # See the detailed comment in .wait().
#    1158     if timeout is not None:
#
# File /usr/lib/python3.10/subprocess.py:2021, in Popen._communicate(self, input, endtime, orig_timeout)
#    2014     self._check_timeout(endtime, orig_timeout,
#    2015                         stdout, stderr,
#    2016                         skip_check_and_raise=True)
#    2017     raise RuntimeError(  # Impossible :)
#    2018         '_check_timeout(..., skip_check_and_raise=True) '
#    2019         'failed to raise TimeoutExpired.')
# -> 2021 ready = selector.select(timeout)
#    2022 self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    2024 # XXX Rewrite these to use non-blocking I/O on the file
#    2025 # objects; they are no longer using C stdio!
#
# File /usr/lib/python3.10/selectors.py:416, in _PollLikeSelector.select(self, timeout)
#     414 ready = []
#     415 try:
# --> 416     fd_event_list = self._selector.poll(timeout)
#     417 except InterruptedError:
#     418     return ready
#
# KeyboardInterrupt:

# %%
plt.figure(figsize=(10, 6))

# PLot latencies for each IP address
for ip in ip_addresses:
    plt.plot(df['Request Number'], df[f'{ip} Latency (ms)'], label=f'{ip}')

plt.title('Ping Latency Over Time')
plt.xlabel('Request Number')
plt.ylabel('Latency (ms)')
plt.legend()
plt.grid(True)
plt.show()
